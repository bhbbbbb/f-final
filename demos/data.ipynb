# %%
# !pip install git+https://github.com/bhbbbbb/f-final

# %% [markdown]
# Data will be downloaded automatically and cached in the directory `dataset`.
#
# Note that `merged_df` has been split with ratio train:val:test=0.7:0.2:0.1 (following hw3).

# %%
from final import data
# data.set_password(<the password>)
merged_dfs = data.merged_df()
print(list(merged_dfs.keys()))
merged_dfs['train'][['loaded_pids', 'products']]
# Out:
# ['train', 'val', 'test']
#                                      loaded_pids                 products
# order_id
# 2305010004468380                      [81, 1404]               {1216, 81}
# 2305010019003044                          [4043]                   {4043}
# 2305010027395991                          [2907]                   {2907}
# 2305010041548766              [4545, 1746, 2312]             {2312, 1746}
# 2305010046021720              [4102, 3568, 4267]  {3568, 1418, 1195, 565}
# ...                                          ...                      ...
# 2306121613151815                          [4356]        {1512, 4356, 701}
# 2306121614297961   [4043, 4102, 4255, 3232, 753]  {3232, 753, 4043, 4102}
# 2306121618585096               [4356, 459, 4356]              {459, 4356}
# 2306121630202724               [3400, 4554, 352]              {3400, 352}
# 2306121641087744  [1210, 1719, 3409, 1746, 2907]       {3409, 1746, 2907}
#
# [15351 rows x 2 columns]

# %%
import final
from pprint import pprint
pprint(final.data.list_all_available_data())
# Out:
# ['N_RPODUCTS',
#  'AVAILABLE_PRODUCT_IDS',
#  'PID_MAPPING',
#  'load_df',
#  'merged_df',
#  'default_user_names',
#  'product_tags_v4',
#  'product_tags_v5_en',
#  'product_tags_v5_zh',
#  'product_keywords']

# %%
print(f'{len(final.AVAILABLE_PRODUCT_IDS) = }')
# Out:
# len(available_product_ids) = 357

# %%
data.load_df()
# Out:
#              timestamp     session_id  \
# 0        1682870401840  1682870397063
# 1        1683122834794  1683122830483
# 2        1683824762906  1683824759107
# 3        1682870450489  1682870182020
# 4        1682870413769  1682869708011
# ...                ...            ...
# 1068114  1688140785888  1688140782110
# 1068115  1688140788307  1688140786830
# 1068116  1688140794786  1688140792450
# 1068117  1688140794255  1688140791262
# 1068118  1688140799125  1688140796726
#
#                                                    url_now  \
# 0        https://i3fresh.tw/cheap_2903.html?utm_source=...
# 1        https://i3fresh.tw/cheap_2312.html?utm_source=...
# 2        https://i3fresh.tw/cheap_2988.html?utm_source=...
# 3                   https://mob.i3fresh.tw/cheap_1930.html
# 4        https://mob.i3fresh.tw/cheap_3972.html?utm_med...
# ...                                                    ...
# 1068114  https://mob.i3fresh.tw/cheap_1758.html?utm_sou...
# 1068115  https://mob.i3fresh.tw/cheap_1758.html?utm_sou...
# 1068116  https://mob.i3fresh.tw/cheap_4675.html?utm_sou...
# 1068117  https://mob.i3fresh.tw/cheap_3976.html?utm_sou...
# 1068118  https://mob.i3fresh.tw/cheap_644.html?RID=C658...
#
#                                               url_referrer  device_type  \
# 0                                  https://l.facebook.com/            0
# 1                                  https://l.facebook.com/            0
# 2                                  https://l.facebook.com/            0
# 3        https://mob.i3fresh.tw/inpage_35_22.html?utm_s...            2
# 4                                  https://mob.i3fresh.tw/            2
# ...                                                    ...          ...
# 1068114                           https://lm.facebook.com/            1
# 1068115                             http://m.facebook.com/            2
# 1068116                            https://l.facebook.com/            1
# 1068117                             http://m.facebook.com/            2
# 1068118                            https://www.google.com/            2
#
#          landing_count  uuid_ind          url_path  item_id item_type  \
# 0                    2         0  /cheap_2903.html     2903     cheap
# 1                    3         0  /cheap_2312.html     2312     cheap
# 2                    4         0  /cheap_2988.html     2988     cheap
# 3                    0         2  /cheap_1930.html     1930     cheap
# 4                    1         3  /cheap_3972.html     3972     cheap
# ...                ...       ...               ...      ...       ...
# 1068114              1   1045539  /cheap_1758.html     1758     cheap
# 1068115              1   1045541  /cheap_1758.html     1758     cheap
# 1068116              1   1045544  /cheap_4675.html     4675     cheap
# 1068117              1   1045545  /cheap_3976.html     3976     cheap
# 1068118              1   1045548   /cheap_644.html      644     cheap
#
#          main_cat  sub_cat
# 0            <NA>     <NA>
# 1            <NA>     <NA>
# 2            <NA>     <NA>
# 3              35       22
# 4            <NA>     <NA>
# ...           ...      ...
# 1068114      <NA>     <NA>
# 1068115      <NA>     <NA>
# 1068116      <NA>     <NA>
# 1068117      <NA>     <NA>
# 1068118      <NA>     <NA>
#
# [1068119 rows x 12 columns]
